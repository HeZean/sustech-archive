# %% [markdown]
# # KDD Assignment 2
# ![CS306](https://img.shields.io/badge/CS306-Data%20Mining-orange) &nbsp;
# ![2022s](https://img.shields.io/badge/semester-2022%20spring-blue)
#
# Author: 何泽安 (He Zean) &nbsp;&nbsp; SID: 12011323

# %% [markdown]
# ## Part 1. Data Collection
#
# We first analyze the network packages, and find the useful API url. We only need the chinaDayList and chinaDayAddList, so we modify the url as shows in the below code.
#
# <img src="https://i.imgur.com/JcNXIGi.png" alt="api capture" style="zoom:25%;" />

# %%
from urllib.request import urlopen
import json

api = 'https://api.inews.qq.com/newsqa/v1/query/inner/publish/modules/list?modules=chinaDayList,chinaDayAddList'
raw_data = urlopen(api).read().decode('utf-8')
raw_data = json.loads(raw_data)['data']

raw_data
# Out:
# {'chinaDayAddList': [{'suspect': 3,
#    'heal': 1521,
#    'localinfectionadd': 2177,
#    'confirm': 3551,
#    'dead': 249,
#    'importedCase': 81,
#    'infect': 2316,
#    'localConfirmadd': 1656,
#    'deadRate': '7.0',
#    'healRate': '42.8',
#    'date': '03.19',
#    'y': '2022'},
#   {'suspect': 6,
#    'dead': 246,
#    'localinfectionadd': 2384,
#    'localConfirmadd': 1947,
#    'deadRate': '7.2',
#    'confirm': 3423,
#    'heal': 1467,
#    'importedCase': 80,
#    'infect': 2492,
#    'healRate': '42.9',
#    'date': '03.20',
#    'y': '2022'},
#   {'heal': 980,
#    'importedCase': 57,
#    'localinfectionadd': 2313,
#    'localConfirmadd': 2281,
#    'deadRate': '6.3',
#    'suspect': 0,
#    'dead': 223,
#    'healRate': '27.5',
#    'date': '03.21',
#    'y': '2022',
#    'confirm': 3563,
#    'infect': 2432},
#   {'confirm': 3813,
#    'dead': 245,
#    'importedCase': 76,
#    'infect': 2469,
#    'localinfectionadd': 2346,
#    'localConfirmadd': 2591,
#    'deadRate': '6.4',
#    'date': '03.22',
#    'y': '2022',
#    'suspect': 3,
#    'heal': 1938,
#    'healRate': '50.8'},
#   {'y': '2022',
#    'confirm': 3218,
#    'heal': 2362,
#    'infect': 2829,
#    'healRate': '73.4',
#    'localConfirmadd': 2010,
#    'deadRate': '6.4',
#    'date': '03.23',
#    'suspect': 1,
#    'dead': 205,
#    'importedCase': 44,
#    'localinfectionadd': 2722},
#   {'heal': 2111,
#    'importedCase': 65,
#    'localConfirmadd': 1301,
#    'deadRate': '6.3',
#    'healRate': '65.9',
#    'suspect': 5,
#    'dead': 201,
#    'infect': 3622,
#    'localinfectionadd': 3489,
#    'date': '03.24',
#    'y': '2022',
#    'confirm': 3204},
#   {'localinfectionadd': 4320,
#    'localConfirmadd': 1280,
#    'healRate': '110.4',
#    'date': '03.25',
#    'y': '2022',
#    'suspect': 1,
#    'dead': 192,
#    'importedCase': 55,
#    'infect': 4430,
#    'deadRate': '9.2',
#    'confirm': 2093,
#    'heal': 2310},
#   {'suspect': 0,
#    'dead': 139,
#    'importedCase': 37,
#    'infect': 4448,
#    'localConfirmadd': 1217,
#    'deadRate': '6.6',
#    'date': '03.26',
#    'confirm': 2121,
#    'y': '2022',
#    'localinfectionadd': 4333,
#    'healRate': '115.3',
#    'heal': 2446},
#   {'confirm': 2164,
#    'dead': 151,
#    'heal': 1925,
#    'importedCase': 56,
#    'infect': 5134,
#    'localinfectionadd': 4996,
#    'localConfirmadd': 1219,
#    'healRate': '89.0',
#    'date': '03.27',
#    'y': '2022',
#    'suspect': 6,
#    'deadRate': '7.0'},
#   {'localConfirmadd': 1228,
#    'deadRate': '8.3',
#    'healRate': '78.7',
#    'dead': 168,
#    'importedCase': 65,
#    'infect': 5758,
#    'localinfectionadd': 5658,
#    'y': '2022',
#    'confirm': 2022,
#    'suspect': 6,
#    'heal': 1591,
#    'date': '03.28'},
#   {'deadRate': '7.0',
#    'date': '03.29',
#    'y': '2022',
#    'suspect': 2,
#    'dead': 151,
#    'infect': 7196,
#    'localinfectionadd': 7090,
#    'localConfirmadd': 1565,
#    'confirm': 2164,
#    'heal': 2578,
#    'importedCase': 64,
#    'healRate': '119.1'},
#   {'localConfirmadd': 1803,
#    'healRate': '107.7',
#    'date': '03.30',
#    'confirm': 2666,
#    'suspect': 2,
#    'heal': 2872,
#    'importedCase': 36,
#    'localinfectionadd': 6651,
#    'y': '2022',
#    'dead': 135,
#    'infect': 6720,
#    'deadRate': '5.1'},
#   {'localConfirmadd': 1787,
#    'deadRate': '4.6',
#    'healRate': '97.8',
#    'date': '03.31',
#    'suspect': 2,
#    'infect': 5559,
#    'heal': 2536,
#    'importedCase': 40,
#    'localinfectionadd': 5442,
#    'y': '2022',
#    'confirm': 2593,
#    'dead': 119},
#   {'localinfectionadd': 7789,
#    'localConfirmadd': 2086,
#    'deadRate': '0.8',
#    'date': '04.01',
#    'y': '2022',
#    'dead': 120,
#    'infect': 7869,
#    'heal': 5781,
#    'importedCase': 43,
#    'healRate': '40.5',
#    'confirm': 14288,
#    'suspect': 0},
#   {'date': '04.02',
#    'suspect': 0,
#    'dead': 116,
#    'importedCase': 51,
#    'deadRate': '1.4',
#    'healRate': '45.6',
#    'y': '2022',
#    'confirm': 8570,
#    'heal': 3907,
#    'infect': 11781,
#    'localinfectionadd': 11691,
#    'localConfirmadd': 1455},
#   {'infect': 11862,
#    'healRate': '125.7',
#    'date': '04.03',
#    'y': '2022',
#    'localinfectionadd': 11771,
#    'localConfirmadd': 1366,
#    'deadRate': '5.1',
#    'confirm': 2163,
#    'suspect': 0,
#    'dead': 111,
#    'heal': 2719,
#    'importedCase': 39},
#   {'suspect': 0,
#    'dead': 90,
#    'heal': 2281,
#    'localConfirmadd': 1173,
#    'y': '2022',
#    'confirm': 1954,
#    'importedCase': 62,
#    'infect': 15355,
#    'localinfectionadd': 15239,
#    'deadRate': '4.6',
#    'healRate': '116.7',
#    'date': '04.04'},
#   {'infect': 19199,
#    'localConfirmadd': 1383,
#    'deadRate': '3.8',
#    'healRate': '148.3',
#    'date': '04.05',
#    'y': '2022',
#    'importedCase': 32,
#    'suspect': 0,
#    'dead': 87,
#    'heal': 3357,
#    'localinfectionadd': 19089,
#    'confirm': 2263},
#   {'date': '04.06',
#    'suspect': 4,
#    'dead': 111,
#    'importedCase': 39,
#    'localinfectionadd': 21711,
#    'localConfirmadd': 1284,
#    'healRate': '115.4',
#    'confirm': 2097,
#    'heal': 2420,
#    'infect': 21784,
#    'deadRate': '5.3',
#    'y': '2022'},
#   {'suspect': 4,
#    'localConfirmadd': 1540,
#    'deadRate': '3.1',
#    'date': '04.07',
#    'y': '2022',
#    'localinfectionadd': 22561,
#    'healRate': '108.5',
#    'confirm': 3096,
#    'dead': 97,
#    'heal': 3358,
#    'importedCase': 36,
#    'infect': 22648},
#   {'importedCase': 33,
#    'localinfectionadd': 25037,
#    'healRate': '170.4',
#    'date': '04.09',
#    'dead': 63,
#    'heal': 3491,
#    'infect': 25111,
#    'localConfirmadd': 1318,
#    'deadRate': '3.1',
#    'y': '2022',
#    'confirm': 2049,
#    'suspect': 0},
#   {'dead': 65,
#    'heal': 2256,
#    'infect': 26411,
#    'localConfirmadd': 1164,
#    'healRate': '112.3',
#    'y': '2022',
#    'confirm': 2009,
#    'suspect': 0,
#    'importedCase': 20,
#    'localinfectionadd': 26345,
#    'deadRate': '3.2',
#    'date': '04.10'},
#   {'importedCase': 21,
#    'localConfirmadd': 1251,
#    'suspect': 0,
#    'dead': 65,
#    'heal': 2554,
#    'deadRate': '3.1',
#    'healRate': '121.8',
#    'date': '04.11',
#    'y': '2022',
#    'confirm': 2097,
#    'infect': 23387,
#    'localinfectionadd': 23295},
#   {'dead': 116,
#    'heal': 3468,
#    'localConfirmadd': 1500,
#    'deadRate': '3.8',
#    'date': '04.12',
#    'y': '2022',
#    'confirm': 3048,
#    'suspect': 0,
#    'importedCase': 13,
#    'infect': 26525,
#    'localinfectionadd': 26420,
#    'healRate': '113.8'},
#   {'suspect': 0,
#    'dead': 62,
#    'importedCase': 21,
#    'localinfectionadd': 26318,
#    'deadRate': '1.5',
#    'healRate': '89.0',
#    'y': '2022',
#    'confirm': 4009,
#    'infect': 26391,
#    'localConfirmadd': 2999,
#    'date': '04.13',
#    'heal': 3568},
#   {'suspect': 1,
#    'importedCase': 14,
#    'localConfirmadd': 3472,
#    'y': '2022',
#    'confirm': 4547,
#    'dead': 54,
#    'heal': 2937,
#    'infect': 20782,
#    'localinfectionadd': 20694,
#    'deadRate': '1.2',
#    'healRate': '64.6',
#    'date': '04.14'},
#   {'dead': 67,
#    'heal': 4529,
#    'localConfirmadd': 3867,
#    'healRate': '83.1',
#    'date': '04.15',
#    'y': '2022',
#    'confirm': 5451,
#    'importedCase': 29,
#    'infect': 20895,
#    'localinfectionadd': 20813,
#    'deadRate': '1.2',
#    'suspect': 0},
#   {'confirm': 4944,
#    'suspect': 0,
#    'heal': 2408,
#    'importedCase': 25,
#    'infect': 22626,
#    'y': '2022',
#    'dead': 41,
#    'localinfectionadd': 22512,
#    'localConfirmadd': 3504,
#    'deadRate': '0.8',
#    'healRate': '48.7',
#    'date': '04.16'},
#   {'heal': 2284,
#    'localinfectionadd': 20639,
#    'localConfirmadd': 2723,
#    'deadRate': '0.7',
#    'y': '2022',
#    'date': '04.17',
#    'confirm': 4305,
#    'suspect': 0,
#    'dead': 32,
#    'importedCase': 19,
#    'infect': 20718,
#    'healRate': '53.1'},
#   {'dead': 27,
#    'heal': 2320,
#    'importedCase': 19,
#    'infect': 18284,
#    'y': '2022',
#    'confirm': 5186,
#    'suspect': 0,
#    'localinfectionadd': 18187,
#    'localConfirmadd': 3297,
#    'deadRate': '0.5',
#    'healRate': '44.7',
#    'date': '04.18'},
#   {'healRate': '64.6',
#    'importedCase': 8,
#    'localinfectionadd': 17066,
#    'localConfirmadd': 2753,
#    'heal': 2962,
#    'infect': 17166,
#    'deadRate': '0.6',
#    'date': '04.19',
#    'y': '2022',
#    'confirm': 4582,
#    'suspect': 1,
#    'dead': 26},
#   {'dead': 18,
#    'heal': 3056,
#    'localinfectionadd': 16552,
#    'healRate': '54.4',
#    'y': '2022',
#    'confirm': 5616,
#    'suspect': 0,
#    'importedCase': 11,
#    'infect': 16617,
#    'localConfirmadd': 2830,
#    'deadRate': '0.3',
#    'date': '04.20'},
#   {'date': '04.21',
#    'confirm': 5309,
#    'importedCase': 14,
#    'heal': 2387,
#    'infect': 16465,
#    'localinfectionadd': 16383,
#    'localConfirmadd': 2119,
#    'deadRate': '0.7',
#    'healRate': '45.0',
#    'suspect': 0,
#    'dead': 37,
#    'y': '2022'},
#   {'localinfectionadd': 21355,
#    'date': '04.22',
#    'dead': 27,
#    'importedCase': 17,
#    'infect': 21423,
#    'localConfirmadd': 2971,
#    'deadRate': '0.4',
#    'healRate': '48.0',
#    'y': '2022',
#    'confirm': 7030,
#    'suspect': 0,
#    'heal': 3371},
#   {'suspect': 0,
#    'importedCase': 14,
#    'localinfectionadd': 20230,
#    'localConfirmadd': 1566,
#    'healRate': '12.5',
#    'y': '2022',
#    'confirm': 23314,
#    'dead': 48,
#    'heal': 2904,
#    'infect': 20285,
#    'deadRate': '0.2',
#    'date': '04.23'},
#   {'deadRate': '0.7',
#    'confirm': 8923,
#    'suspect': 0,
#    'heal': 3151,
#    'importedCase': 14,
#    'localinfectionadd': 17528,
#    'y': '2022',
#    'dead': 64,
#    'infect': 17581,
#    'localConfirmadd': 2666,
#    'healRate': '35.3',
#    'date': '04.24'},
#   {'dead': 70,
#    'localinfectionadd': 15816,
#    'localConfirmadd': 1908,
#    'deadRate': '1.0',
#    'healRate': '32.9',
#    'y': '2022',
#    'suspect': 0,
#    'heal': 2385,
#    'importedCase': 15,
#    'infect': 15889,
#    'date': '04.25',
#    'confirm': 7259},
#   {'confirm': 8251,
#    'heal': -6587,
#    'importedCase': 6,
#    'localConfirmadd': 1818,
#    'deadRate': '0.7',
#    'healRate': '0.0',
#    'y': '2022',
#    'suspect': 0,
#    'dead': 55,
#    'infect': 12474,
#    'localinfectionadd': 12404,
#    'date': '04.26'},
#   {'confirm': 10561,
#    'infect': 9864,
#    'localConfirmadd': 1494,
#    'deadRate': '0.5',
#    'healRate': '27.8',
#    'date': '04.27',
#    'y': '2022',
#    'suspect': 0,
#    'dead': 57,
#    'heal': 2935,
#    'importedCase': 9,
#    'localinfectionadd': 9791},
#   {'infect': 10029,
#    'deadRate': '0.4',
#    'healRate': '17.4',
#    'y': '2022',
#    'confirm': 18157,
#    'dead': 69,
#    'heal': 3165,
#    'localConfirmadd': 5646,
#    'date': '04.28',
#    'suspect': 0,
#    'importedCase': 13,
#    'localinfectionadd': 9942},
#   {'localinfectionadd': 9293,
#    'date': '04.29',
#    'suspect': 0,
#    'dead': 47,
#    'heal': 3639,
#    'localConfirmadd': 1410,
#    'deadRate': '0.3',
#    'healRate': '26.3',
#    'y': '2022',
#    'confirm': 13842,
#    'importedCase': 14,
#    'infect': 9369},
#   {'confirm': 16121,
#    'suspect': 0,
#    'importedCase': 4,
#    'infect': 7409,
#    'y': '2022',
#    'dead': 51,
#    'heal': 3635,
#    'localinfectionadd': 7340,
#    'localConfirmadd': 916,
#    'deadRate': '0.3',
#    'healRate': '22.5',
#    'date': '04.30'},
#   {'confirm': 17973,
#    'dead': 45,
#    'heal': 4850,
#    'localConfirmadd': 827,
#    'deadRate': '0.3',
#    'healRate': '27.0',
#    'y': '2022',
#    'suspect': 0,
#    'importedCase': 4,
#    'infect': 7409,
#    'localinfectionadd': 7340,
#    'date': '05.01'},
#   {'healRate': '24.2',
#    'date': '05.02',
#    'y': '2022',
#    'suspect': 1,
#    'dead': 28,
#    'localinfectionadd': 5647,
#    'localConfirmadd': 368,
#    'deadRate': '0.2',
#    'confirm': 18285,
#    'heal': 4428,
#    'importedCase': 16,
#    'infect': 5690},
#   {'suspect': 0,
#    'deadRate': '0.1',
#    'y': '2022',
#    'localConfirmadd': 353,
#    'healRate': '9.2',
#    'confirm': 23603,
#    'dead': 28,
#    'heal': 2167,
#    'importedCase': 9,
#    'infect': 5136,
#    'localinfectionadd': 5075,
#    'date': '05.03'},
#   {'heal': 2287,
#    'date': '05.04',
#    'y': '2022',
#    'localinfectionadd': 4678,
#    'localConfirmadd': 360,
#    'deadRate': '0.1',
#    'confirm': 28951,
#    'suspect': 0,
#    'dead': 21,
#    'importedCase': 13,
#    'infect': 4740,
#    'healRate': '7.9'},
#   {'date': '05.05',
#    'confirm': 30473,
#    'dead': 22,
#    'heal': 1745,
#    'localinfectionadd': 4272,
#    'localConfirmadd': 356,
#    'y': '2022',
#    'suspect': 0,
#    'importedCase': 18,
#    'infect': 4340,
#    'deadRate': '0.1',
#    'healRate': '5.7'},
#   {'deadRate': '0.1',
#    'healRate': '5.7',
#    'date': '05.06',
#    'suspect': 1,
#    'dead': 34,
#    'importedCase': 6,
#    'localConfirmadd': 345,
#    'y': '2022',
#    'confirm': 36602,
#    'heal': 2082,
#    'infect': 4324,
#    'localinfectionadd': 4275},
#   {'localConfirmadd': 319,
#    'healRate': '2.7',
#    'suspect': 0,
#    'heal': 1275,
#    'infect': 4133,
#    'localinfectionadd': 4065,
#    'deadRate': '0.0',
#    'date': '05.07',
#    'y': '2022',
#    'confirm': 46793,
#    'dead': 19,
#    'importedCase': 10},
#   {'heal': 966,
#    'importedCase': 14,
#    'localConfirmadd': 401,
#    'date': '05.08',
#    'dead': 25,
#    'suspect': 0,
#    'infect': 3918,
#    'localinfectionadd': 3859,
#    'deadRate': '0.1',
#    'healRate': '2.3',
#    'y': '2022',
#    'confirm': 42746},
#   {'dead': 19,
#    'heal': 1055,
#    'deadRate': '0.0',
#    'date': '05.09',
#    'confirm': 40622,
#    'importedCase': 8,
#    'infect': 3118,
#    'localinfectionadd': 3077,
#    'localConfirmadd': 349,
#    'healRate': '2.6',
#    'y': '2022',
#    'suspect': 0},
#   {'suspect': 0,
#    'dead': 24,
#    'heal': 899,
#    'importedCase': 22,
#    'infect': 1603,
#    'localinfectionadd': 1545,
#    'localConfirmadd': 302,
#    'date': '05.10',
#    'y': '2022',
#    'confirm': 51198,
#    'deadRate': '0.0',
#    'healRate': '1.8'},
#   {'confirm': 57428,
#    'suspect': 1,
#    'dead': 16,
#    'importedCase': 15,
#    'heal': 694,
#    'infect': 1680,
#    'localinfectionadd': 1630,
#    'localConfirmadd': 222,
#    'deadRate': '0.0',
#    'healRate': '1.2',
#    'date': '05.11',
#    'y': '2022'},
#   {'suspect': 0,
#    'dead': 2,
#    'infect': 2201,
#    'deadRate': '0.0',
#    'healRate': '0.9',
#    'date': '05.12',
#    'confirm': 65794,
#    'heal': 614,
#    'importedCase': 19,
#    'localinfectionadd': 2140,
#    'localConfirmadd': 312,
#    'y': '2022'},
#   {'y': '2022',
#    'confirm': 65317,
#    'infect': 1796,
#    'localConfirmadd': 253,
#    'deadRate': '0.0',
#    'date': '05.13',
#    'healRate': '1.3',
#    'suspect': 0,
#    'dead': 1,
#    'heal': 866,
#    'importedCase': 23,
#    'localinfectionadd': 1726},
#   {'dead': 44,
#    'heal': 538,
#    'infect': 1550,
#    'deadRate': '0.1',
#    'date': '05.14',
#    'y': '2022',
#    'confirm': 64238,
#    'suspect': 0,
#    'importedCase': 13,
#    'localinfectionadd': 1492,
#    'localConfirmadd': 226,
#    'healRate': '0.8'},
#   {'confirm': 68916,
#    'importedCase': 11,
#    'localConfirmadd': 140,
#    'date': '05.15',
#    'y': '2022',
#    'suspect': 0,
#    'dead': 24,
#    'heal': 708,
#    'infect': 1076,
#    'localinfectionadd': 1019,
#    'deadRate': '0.0',
#    'healRate': '1.0'},
#   {'date': '05.16',
#    'y': '2022',
#    'suspect': 0,
#    'dead': 30,
#    'heal': 515,
#    'localinfectionadd': 887,
#    'localConfirmadd': 162,
#    'deadRate': '0.0',
#    'confirm': 61933,
#    'importedCase': 13,
#    'infect': 925,
#    'healRate': '0.8'},
#   {'date': '05.17',
#    'y': '2022',
#    'suspect': 0,
#    'heal': 477,
#    'importedCase': 13,
#    'localinfectionadd': 1000,
#    'deadRate': '0.1',
#    'healRate': '0.7',
#    'confirm': 66109,
#    'dead': 41,
#    'infect': 1065,
#    'localConfirmadd': 227},
#   {'date': '05.18',
#    'confirm': 85364,
#    'suspect': 0,
#    'dead': 46,
#    'heal': 504,
#    'infect': 870,
#    'y': '2022',
#    'importedCase': 21,
#    'localinfectionadd': 825,
#    'localConfirmadd': 191,
#    'deadRate': '0.1',
#    'healRate': '0.6'}],
#  'chinaDayList': [{'deadRate': '2.6',
#    'date': '03.20',
#    'y': '2022',
#    'localConfirmH5': 19617,
#    'suspect': 14,
#    'dead': 11387,
#    'nowConfirm': 265370,
#    'nowSevere': 39,
#    'confirm': 431271,
#    'healRate': '35.8',
#    'noInfect': 18327,
#    'noInfectH5': 16669,
#    'local_acc_confirm': 132226,
#    'heal': 154514,
#    'importedCase': 16920,
#    'localConfirm': 19617},
#   {'nowSevere': 42,
#    'noInfect': 20155,
#    'localConfirm': 21507,
#    'local_acc_confirm': 134564,
#    'confirm': 434834,
#    'suspect': 14,
#    'deadRate': '2.7',
#    'healRate': '35.8',
#    'noInfectH5': 18521,
#    'dead': 11610,
#    'importedCase': 16976,
#    'nowConfirm': 267730,
#    'y': '2022',
#    'localConfirmH5': 21507,
#    'heal': 155494,
#    'date': '03.21'},
#   {'deadRate': '2.7',
#    'healRate': '35.9',
#    'date': '03.22',
#    'suspect': 12,
#    'dead': 11855,
#    'heal': 157432,
#    'importedCase': 17052,
#    'confirm': 438647,
#    'nowSevere': 50,
#    'noInfect': 22000,
#    'local_acc_confirm': 137231,
#    'localConfirmH5': 23659,
#    'nowConfirm': 269360,
#    'y': '2022',
#    'localConfirm': 23659,
#    'noInfectH5': 20411},
#   {'noInfect': 24062,
#    'localConfirm': 24953,
#    'noInfectH5': 22564,
#    'localConfirmH5': 24953,
#    'heal': 159794,
#    'nowSevere': 50,
#    'date': '03.23',
#    'confirm': 441865,
#    'dead': 12060,
#    'nowConfirm': 270011,
#    'local_acc_confirm': 139285,
#    'suspect': 13,
#    'importedCase': 17096,
#    'deadRate': '2.7',
#    'healRate': '36.2',
#    'y': '2022'},
#   {'suspect': 16,
#    'healRate': '36.4',
#    'noInfect': 27046,
#    'confirm': 445069,
#    'dead': 12261,
#    'heal': 161905,
#    'nowSevere': 50,
#    'y': '2022',
#    'localConfirmH5': 25710,
#    'importedCase': 17161,
#    'nowConfirm': 270903,
#    'deadRate': '2.8',
#    'date': '03.24',
#    'localConfirm': 25710,
#    'noInfectH5': 25591,
#    'local_acc_confirm': 140651},
#   {'noInfect': 30850,
#    'confirm': 447162,
#    'dead': 12453,
#    'nowConfirm': 270494,
#    'deadRate': '2.8',
#    'healRate': '36.7',
#    'y': '2022',
#    'heal': 164215,
#    'importedCase': 17216,
#    'noInfectH5': 29443,
#    'localConfirmH5': 26218,
#    'local_acc_confirm': 141986,
#    'suspect': 13,
#    'nowSevere': 50,
#    'date': '03.25',
#    'localConfirm': 26218},
#   {'healRate': '37.1',
#    'date': '03.26',
#    'local_acc_confirm': 143240,
#    'confirm': 449283,
#    'importedCase': 17253,
#    'noInfectH5': 33170,
#    'suspect': 13,
#    'nowConfirm': 270030,
#    'y': '2022',
#    'noInfect': 34508,
#    'localConfirmH5': 26571,
#    'dead': 12592,
#    'heal': 166661,
#    'localConfirm': 26571,
#    'nowSevere': 53,
#    'deadRate': '2.8'},
#   {'suspect': 19,
#    'nowConfirm': 270118,
#    'nowSevere': 58,
#    'localConfirm': 26831,
#    'localConfirmH5': 26831,
#    'local_acc_confirm': 144515,
#    'noInfectH5': 37291,
#    'confirm': 451447,
#    'dead': 12743,
#    'heal': 168586,
#    'importedCase': 17309,
#    'deadRate': '2.8',
#    'y': '2022',
#    'noInfect': 38649,
#    'healRate': '37.3',
#    'date': '03.27'},
#   {'confirm': 453469,
#    'suspect': 15,
#    'dead': 12911,
#    'nowSevere': 59,
#    'localConfirmH5': 27021,
#    'heal': 170177,
#    'nowConfirm': 270382,
#    'importedCase': 17370,
#    'local_acc_confirm': 145808,
#    'deadRate': '2.8',
#    'healRate': '37.5',
#    'localConfirm': 27021,
#    'noInfectH5': 42116,
#    'date': '03.28',
#    'y': '2022',
#    'noInfect': 43425},
#   {'localConfirmH5': 27372,
#    'local_acc_confirm': 147437,
#    'nowSevere': 62,
#    'importedCase': 17434,
#    'noInfect': 49421,
#    'noInfectH5': 48154,
#    'confirm': 455633,
#    'suspect': 17,
#    'nowConfirm': 269816,
#    'dead': 13062,
#    'date': '03.29',
#    'localConfirm': 27372,
#    'heal': 172755,
#    'deadRate': '2.9',
#    'healRate': '37.9',
#    'y': '2022'},
#   {'local_acc_confirm': 149276,
#    'suspect': 18,
#    'importedCase': 17470,
#    'healRate': '38.3',
#    'date': '03.30',
#    'y': '2022',
#    'noInfectH5': 53709,
#    'localConfirmH5': 27843,
#    'confirm': 458299,
#    'heal': 175627,
#    'dead': 13197,
#    'nowConfirm': 269475,
#    'nowSevere': 66,
#    'deadRate': '2.9',
#    'noInfect': 54911,
#    'localConfirm': 27843},
#   {'confirm': 460892,
#    'suspect': 20,
#    'heal': 178163,
#    'importedCase': 17510,
#    'localConfirm': 29306,
#    'healRate': '38.7',
#    'date': '03.31',
#    'localConfirmH5': 29306,
#    'local_acc_confirm': 151103,
#    'nowConfirm': 269413,
#    'nowSevere': 66,
#    'noInfect': 57874,
#    'noInfectH5': 59056,
#    'dead': 13316,
#    'deadRate': '2.9',
#    'y': '2022'},
#   {'healRate': '38.7',
#    'y': '2022',
#    'localConfirm': 26467,
#    'confirm': 475180,
#    'nowSevere': 58,
#    'importedCase': 17553,
#    'date': '04.01',
#    'local_acc_confirm': 153232,
#    'suspect': 19,
#    'nowConfirm': 277800,
#    'noInfect': 63886,
#    'noInfectH5': 62768,
#    'dead': 13436,
#    'heal': 183944,
#    'deadRate': '2.8',
#    'localConfirmH5': 26467},
#   {'nowSevere': 57,
#    'localConfirmH5': 25514,
#    'deadRate': '2.8',
#    'healRate': '38.8',
#    'localConfirm': 25514,
#    'dead': 13552,
#    'heal': 187850,
#    'nowConfirm': 282348,
#    'importedCase': 17604,
#    'suspect': 19,
#    'y': '2022',
#    'noInfectH5': 72584,
#    'local_acc_confirm': 154738,
#    'confirm': 483750,
#    'date': '04.02',
#    'noInfect': 73689},
#   {'dead': 13663,
#    'deadRate': '2.8',
#    'healRate': '39.2',
#    'localConfirmH5': 25105,
#    'confirm': 485913,
#    'y': '2022',
#    'noInfect': 83364,
#    'noInfectH5': 82300,
#    'suspect': 17,
#    'date': '04.03',
#    'localConfirm': 25105,
#    'local_acc_confirm': 156143,
#    'nowConfirm': 281681,
#    'nowSevere': 54,
#    'importedCase': 17643,
#    'heal': 190569},
#   {'y': '2022',
#    'localConfirmH5': 24469,
#    'confirm': 487867,
#    'suspect': 17,
#    'heal': 192850,
#    'nowConfirm': 281264,
#    'nowSevere': 63,
#    'healRate': '39.5',
#    'local_acc_confirm': 157378,
#    'dead': 13753,
#    'importedCase': 17705,
#    'localConfirm': 24469,
#    'noInfect': 96803,
#    'noInfectH5': 95777,
#    'deadRate': '2.8',
#    'date': '04.04'},
#   {'importedCase': 17737,
#    'localConfirm': 24024,
#    'noInfectH5': 112937,
#    'localConfirmH5': 24024,
#    'confirm': 490130,
#    'deadRate': '2.8',
#    'date': '04.05',
#    'noInfect': 113950,
#    'local_acc_confirm': 158793,
#    'suspect': 16,
#    'heal': 196207,
#    'healRate': '40.0',
#    'y': '2022',
#    'dead': 13840,
#    'nowConfirm': 280083,
#    'nowSevere': 75},
#   {'date': '04.06',
#    'localConfirm': 23626,
#    'noInfectH5': 131955,
#    'confirm': 492227,
#    'suspect': 19,
#    'nowSevere': 85,
#    'importedCase': 17776,
#    'deadRate': '2.8',
#    'localConfirmH5': 23626,
#    'healRate': '40.4',
#    'dead': 13951,
#    'heal': 198627,
#    'nowConfirm': 279649,
#    'noInfect': 132948,
#    'y': '2022',
#    'local_acc_confirm': 160116},
#   {'dead': 14048,
#    'nowConfirm': 279290,
#    'healRate': '40.8',
#    'localConfirmH5': 13353,
#    'local_acc_confirm': 161692,
#    'confirm': 495323,
#    'noInfect': 152693,
#    'deadRate': '2.8',
#    'y': '2022',
#    'localConfirm': 13353,
#    'noInfectH5': 151728,
#    'heal': 201985,
#    'nowSevere': 77,
#    'importedCase': 17812,
#    'date': '04.07',
#    'suspect': 23},
#   {'confirm': 497437,
#    'dead': 14134,
#    'nowConfirm': 277812,
#    'nowSevere': 79,
#    'suspect': 29,
#    'importedCase': 17828,
#    'local_acc_confirm': 163042,
#    'healRate': '41.3',
#    'date': '04.08',
#    'y': '2022',
#    'noInfect': 174015,
#    'localConfirm': 22744,
#    'heal': 205491,
#    'deadRate': '2.8',
#    'noInfectH5': 173083,
#    'localConfirmH5': 22744},
#   {'date': '04.09',
#    'confirm': 499486,
#    'dead': 14197,
#    'nowSevere': 80,
#    'noInfect': 195948,
#    'noInfectH5': 195021,
#    'importedCase': 17861,
#    'suspect': 28,
#    'heal': 208982,
#    'nowConfirm': 276307,
#    'deadRate': '2.8',
#    'healRate': '41.8',
#    'y': '2022',
#    'localConfirm': 22589,
#    'localConfirmH5': 22589,
#    'local_acc_confirm': 164393},
#   {'heal': 211238,
#    'nowConfirm': 275995,
#    'healRate': '42.1',
#    'y': '2022',
#    'dead': 14262,
#    'nowSevere': 76,
#    'deadRate': '2.8',
#    'local_acc_confirm': 165577,
#    'date': '04.10',
#    'noInfect': 219896,
#    'noInfectH5': 218997,
#    'localConfirm': 22025,
#    'localConfirmH5': 22025,
#    'confirm': 501495,
#    'suspect': 28,
#    'importedCase': 17881},
#   {'nowConfirm': 275972,
#    'deadRate': '2.8',
#    'date': '04.11',
#    'local_acc_confirm': 140220,
#    'dead': 14319,
#    'heal': 213274,
#    'y': '2022',
#    'noInfectH5': 239737,
#    'localConfirmH5': 21991,
#    'confirm': 503565,
#    'suspect': 26,
#    'healRate': '42.4',
#    'nowSevere': 77,
#    'importedCase': 17902,
#    'noInfect': 240624,
#    'localConfirm': 21991},
#   {'dead': 14378,
#    'heal': 216382,
#    'healRate': '42.8',
#    'nowConfirm': 275055,
#    'nowSevere': 87,
#    'y': '2022',
#    'local_acc_confirm': 168362,
#    'localConfirmH5': 21512,
#    'confirm': 505815,
#    'importedCase': 17915,
#    'noInfect': 258374,
#    'localConfirm': 21512,
#    'noInfectH5': 257493,
#    'suspect': 26,
#    'deadRate': '2.8',
#    'date': '04.12'},
#   {'deadRate': '2.8',
#    'suspect': 15,
#    'heal': 219950,
#    'dead': 14440,
#    'y': '2022',
#    'noInfect': 266230,
#    'localConfirm': 22514,
#    'confirm': 509824,
#    'nowConfirm': 275434,
#    'nowSevere': 78,
#    'importedCase': 17936,
#    'healRate': '43.1',
#    'date': '04.13',
#    'noInfectH5': 265386,
#    'localConfirmH5': 22514,
#    'local_acc_confirm': 171382},
#   {'confirm': 514371,
#    'suspect': 16,
#    'dead': 14494,
#    'importedCase': 17950,
#    'healRate': '43.3',
#    'date': '04.14',
#    'localConfirm': 24595,
#    'noInfectH5': 275843,
#    'y': '2022',
#    'local_acc_confirm': 174868,
#    'heal': 222887,
#    'nowSevere': 76,
#    'deadRate': '2.8',
#    'noInfect': 276632,
#    'localConfirmH5': 24595,
#    'nowConfirm': 276990},
#   {'suspect': 12,
#    'noInfect': 274676,
#    'nowSevere': 74,
#    'deadRate': '2.8',
#    'localConfirm': 25697,
#    'localConfirmH5': 25697,
#    'nowConfirm': 277854,
#    'importedCase': 17979,
#    'date': '04.15',
#    'y': '2022',
#    'local_acc_confirm': 178764,
#    'confirm': 519822,
#    'dead': 14561,
#    'heal': 227416,
#    'healRate': '43.7',
#    'noInfectH5': 273905},
#   {'confirm': 524766,
#    'nowSevere': 78,
#    'healRate': '43.8',
#    'date': '04.16',
#    'localConfirm': 27629,
#    'noInfectH5': 283024,
#    'deadRate': '2.8',
#    'localConfirmH5': 27629,
#    'suspect': 12,
#    'dead': 14602,
#    'heal': 229824,
#    'importedCase': 18004,
#    'noInfect': 283814,
#    'nowConfirm': 280340,
#    'y': '2022',
#    'local_acc_confirm': 182293},
#   {'dead': 14634,
#    'noInfect': 282764,
#    'localConfirmH5': 28730,
#    'deadRate': '2.8',
#    'heal': 232108,
#    'nowConfirm': 282329,
#    'nowSevere': 71,
#    'confirm': 529071,
#    'suspect': 5,
#    'importedCase': 18023,
#    'healRate': '43.9',
#    'date': '04.17',
#    'y': '2022',
#    'localConfirm': 28730,
#    'noInfectH5': 281992,
#    'local_acc_confirm': 185035},
#   {'suspect': 5,
#    'noInfectH5': 275745,
#    'localConfirmH5': 30134,
#    'date': '04.18',
#    'confirm': 534257,
#    'nowSevere': 75,
#    'importedCase': 18042,
#    'nowConfirm': 285168,
#    'deadRate': '2.7',
#    'localConfirm': 30134,
#    'y': '2022',
#    'noInfect': 276499,
#    'local_acc_confirm': 188351,
#    'dead': 14661,
#    'heal': 234428,
#    'healRate': '43.9'},
#   {'localConfirmH5': 30537,
#    'dead': 14687,
#    'nowSevere': 116,
#    'healRate': '44.1',
#    'date': '04.19',
#    'importedCase': 18050,
#    'confirm': 538839,
#    'suspect': 6,
#    'noInfectH5': 265538,
#    'noInfect': 266288,
#    'localConfirm': 30537,
#    'local_acc_confirm': 191112,
#    'heal': 237390,
#    'nowConfirm': 286762,
#    'deadRate': '2.7',
#    'y': '2022'},
#   {'heal': 240448,
#    'healRate': '44.2',
#    'noInfectH5': 260517,
#    'nowConfirm': 289302,
#    'localConfirmH5': 31188,
#    'local_acc_confirm': 193953,
#    'confirm': 544455,
#    'suspect': 2,
#    'nowSevere': 223,
#    'noInfect': 261262,
#    'localConfirm': 31188,
#    'dead': 14705,
#    'importedCase': 18061,
#    'deadRate': '2.7',
#    'date': '04.20',
#    'y': '2022'},
#   {'heal': 242835,
#    'deadRate': '2.7',
#    'healRate': '44.2',
#    'noInfectH5': 248781,
#    'local_acc_confirm': 196086,
#    'confirm': 549764,
#    'dead': 14742,
#    'localConfirmH5': 30595,
#    'nowSevere': 251,
#    'importedCase': 18075,
#    'localConfirm': 30595,
#    'date': '04.21',
#    'y': '2022',
#    'noInfect': 249507,
#    'suspect': 2,
#    'nowConfirm': 292187},
#   {'confirm': 556794,
#    'dead': 14769,
#    'local_acc_confirm': 199074,
#    'nowSevere': 237,
#    'deadRate': '2.7',
#    'noInfect': 247348,
#    'localConfirm': 30444,
#    'localConfirmH5': 30444,
#    'nowConfirm': 295819,
#    'importedCase': 18092,
#    'date': '04.22',
#    'suspect': 2,
#    'heal': 246206,
#    'healRate': '44.2',
#    'y': '2022',
#    'noInfectH5': 246645},
#   {'localConfirm': 30444,
#    'noInfectH5': 246645,
#    'heal': 249110,
#    'date': '04.23',
#    'noInfect': 249212,
#    'local_acc_confirm': 200654,
#    'nowConfirm': 316181,
#    'healRate': '42.9',
#    'nowSevere': 236,
#    'importedCase': 18106,
#    'y': '2022',
#    'suspect': 2,
#    'dead': 14817,
#    'localConfirmH5': 30444,
#    'confirm': 580108,
#    'deadRate': '2.6'},
#   {'confirm': 589031,
#    'y': '2022',
#    'noInfectH5': 246645,
#    'localConfirmH5': 30444,
#    'local_acc_confirm': 203334,
#    'suspect': 2,
#    'nowConfirm': 321889,
#    'healRate': '42.8',
#    'date': '04.24',
#    'localConfirm': 30444,
#    'dead': 14881,
#    'importedCase': 18120,
#    'deadRate': '2.5',
#    'heal': 252261,
#    'nowSevere': 274,
#    'noInfect': 245343},
#   {'noInfect': 246139,
#    'confirm': 586290,
#    'dead': 14951,
#    'heal': 254646,
#    'nowConfirm': 326693,
#    'suspect': 2,
#    'localConfirmH5': 28523,
#    'date': '04.25',
#    'local_acc_confirm': 205257,
#    'nowSevere': 341,
#    'importedCase': 18135,
#    'deadRate': '2.6',
#    'healRate': '43.4',
#    'y': '2022',
#    'localConfirm': 28523,
#    'noInfectH5': 245543},
#   {'localConfirm': 26579,
#    'localConfirmH5': 26579,
#    'dead': 15006,
#    'deadRate': '2.5',
#    'noInfect': 225249,
#    'healRate': '41.0',
#    'y': '2022',
#    'confirm': 604541,
#    'nowConfirm': 341476,
#    'importedCase': 18141,
#    'date': '04.26',
#    'noInfectH5': 224647,
#    'local_acc_confirm': 207081,
#    'suspect': 0,
#    'heal': 248059,
#    'nowSevere': 318},
#   {'date': '04.27',
#    'localConfirm': 25323,
#    'noInfectH5': 207613,
#    'deadRate': '2.4',
#    'healRate': '40.8',
#    'localConfirmH5': 25323,
#    'confirm': 615102,
#    'heal': 250994,
#    'nowConfirm': 349045,
#    'importedCase': 18150,
#    'noInfect': 208195,
#    'suspect': 0,
#    'dead': 15063,
#    'local_acc_confirm': 208584,
#    'nowSevere': 399,
#    'y': '2022'},
#   {'date': '04.28',
#    'local_acc_confirm': 214243,
#    'dead': 15122,
#    'heal': 253948,
#    'nowConfirm': 364189,
#    'nowSevere': 417,
#    'localConfirmH5': 28135,
#    'localConfirm': 28135,
#    'noInfectH5': 196612,
#    'confirm': 633259,
#    'suspect': 0,
#    'importedCase': 18163,
#    'deadRate': '2.4',
#    'healRate': '40.1',
#    'y': '2022',
#    'noInfect': 197213},
#   {'confirm': 647101,
#    'nowConfirm': 374701,
#    'importedCase': 18177,
#    'deadRate': '2.3',
#    'dead': 15182,
#    'y': '2022',
#    'heal': 257218,
#    'localConfirmH5': 26403,
#    'suspect': 0,
#    'nowSevere': 458,
#    'healRate': '39.7',
#    'date': '04.29',
#    'noInfect': 191036,
#    'localConfirm': 26403,
#    'noInfectH5': 190447,
#    'local_acc_confirm': 215667},
#   {'noInfect': 180362,
#    'suspect': 0,
#    'dead': 15233,
#    'localConfirm': 23846,
#    'localConfirmH5': 23846,
#    'nowConfirm': 387136,
#    'nowSevere': 447,
#    'healRate': '39.3',
#    'y': '2022',
#    'local_acc_confirm': 216587,
#    'confirm': 663222,
#    'heal': 260853,
#    'importedCase': 18181,
#    'deadRate': '2.3',
#    'date': '04.30',
#    'noInfectH5': 179772},
#   {'date': '05.01',
#    'y': '2022',
#    'noInfect': 180362,
#    'local_acc_confirm': 217452,
#    'confirm': 681214,
#    'nowConfirm': 400434,
#    'importedCase': 18200,
#    'deadRate': '2.2',
#    'noInfectH5': 179772,
#    'dead': 15265,
#    'heal': 265672,
#    'nowSevere': 576,
#    'healRate': '39.0',
#    'localConfirmH5': 24692,
#    'suspect': 0,
#    'localConfirm': 24692},
#   {'dead': 15301,
#    'localConfirmH5': 16098,
#    'confirm': 699499,
#    'nowSevere': 615,
#    'noInfect': 180362,
#    'localConfirm': 16098,
#    'date': '05.02',
#    'healRate': '38.6',
#    'y': '2022',
#    'noInfectH5': 133610,
#    'suspect': 0,
#    'heal': 270021,
#    'nowConfirm': 414177,
#    'importedCase': 18216,
#    'deadRate': '2.2',
#    'local_acc_confirm': 217836},
#   {'localConfirm': 14360,
#    'noInfectH5': 127790,
#    'nowSevere': 620,
#    'importedCase': 18225,
#    'date': '05.03',
#    'y': '2022',
#    'noInfect': 128319,
#    'local_acc_confirm': 218198,
#    'confirm': 723102,
#    'nowConfirm': 435585,
#    'deadRate': '2.1',
#    'localConfirmH5': 14360,
#    'heal': 272188,
#    'healRate': '37.6',
#    'suspect': 1,
#    'dead': 15329},
#   {'nowConfirm': 462228,
#    'healRate': '36.5',
#    'date': '05.04',
#    'confirm': 752053,
#    'nowSevere': 650,
#    'deadRate': '2.0',
#    'noInfect': 118737,
#    'local_acc_confirm': 218571,
#    'heal': 274475,
#    'y': '2022',
#    'localConfirm': 12590,
#    'noInfectH5': 118211,
#    'localConfirmH5': 12590,
#    'importedCase': 18238,
#    'dead': 15350,
#    'suspect': 1},
#   {'dead': 15372,
#    'heal': 276220,
#    'deadRate': '2.0',
#    'localConfirmH5': 11515,
#    'localConfirm': 11515,
#    'confirm': 782526,
#    'suspect': 1,
#    'importedCase': 18256,
#    'y': '2022',
#    'noInfect': 111906,
#    'nowSevere': 659,
#    'date': '05.05',
#    'noInfectH5': 111401,
#    'nowConfirm': 490934,
#    'healRate': '35.3',
#    'local_acc_confirm': 218945},
#   {'suspect': 1,
#    'nowSevere': 587,
#    'importedCase': 18262,
#    'noInfect': 103935,
#    'localConfirm': 9812,
#    'localConfirmH5': 9812,
#    'confirm': 819128,
#    'deadRate': '1.9',
#    'healRate': '34.0',
#    'y': '2022',
#    'local_acc_confirm': 219296,
#    'nowConfirm': 525420,
#    'date': '05.06',
#    'heal': 278302,
#    'noInfectH5': 103446,
#    'dead': 15406},
#   {'deadRate': '1.8',
#    'noInfectH5': 97512,
#    'localConfirmH5': 9021,
#    'confirm': 865921,
#    'nowConfirm': 570919,
#    'date': '05.07',
#    'noInfect': 201447,
#    'suspect': 1,
#    'heal': 279577,
#    'nowSevere': 533,
#    'dead': 15425,
#    'healRate': '32.3',
#    'y': '2022',
#    'localConfirm': 9021,
#    'local_acc_confirm': 219625,
#    'importedCase': 18272},
#   {'dead': 15450,
#    'date': '05.08',
#    'y': '2022',
#    'heal': 280543,
#    'nowConfirm': 612674,
#    'nowSevere': 529,
#    'importedCase': 18286,
#    'localConfirm': 8578,
#    'confirm': 908667,
#    'healRate': '30.9',
#    'noInfect': 92564,
#    'noInfectH5': 92090,
#    'suspect': 0,
#    'deadRate': '1.7',
#    'localConfirmH5': 8578,
#    'local_acc_confirm': 220040},
#   {'nowSevere': 511,
#    'deadRate': '1.6',
#    'healRate': '29.7',
#    'date': '05.09',
#    'y': '2022',
#    'localConfirm': 7914,
#    'confirm': 949289,
#    'suspect': 0,
#    'heal': 281598,
#    'nowConfirm': 652222,
#    'importedCase': 18294,
#    'dead': 15469,
#    'noInfect': 87294,
#    'noInfectH5': 86842,
#    'localConfirmH5': 7914,
#    'local_acc_confirm': 220397},
#   {'nowSevere': 484,
#    'y': '2022',
#    'noInfect': 79926,
#    'localConfirmH5': 7403,
#    'suspect': 0,
#    'dead': 15493,
#    'importedCase': 18316,
#    'deadRate': '1.5',
#    'date': '05.10',
#    'noInfectH5': 79461,
#    'local_acc_confirm': 220721,
#    'confirm': 1000487,
#    'heal': 282497,
#    'nowConfirm': 702497,
#    'healRate': '28.2',
#    'localConfirm': 7403},
#   {'noInfectH5': 75098,
#    'nowConfirm': 759215,
#    'importedCase': 18331,
#    'noInfect': 75532,
#    'healRate': '26.8',
#    'localConfirmH5': 7058,
#    'local_acc_confirm': 220958,
#    'y': '2022',
#    'localConfirm': 7058,
#    'suspect': 1,
#    'nowSevere': 444,
#    'date': '05.11',
#    'deadRate': '1.5',
#    'confirm': 1057915,
#    'dead': 15509,
#    'heal': 283191},
#   {'healRate': '25.3',
#    'localConfirmH5': 6760,
#    'local_acc_confirm': 221289,
#    'nowConfirm': 824244,
#    'nowSevere': 397,
#    'y': '2022',
#    'confirm': 1123709,
#    'importedCase': 18350,
#    'deadRate': '1.4',
#    'noInfect': 70770,
#    'noInfectH5': 70323,
#    'dead': 15529,
#    'heal': 283936,
#    'date': '05.12',
#    'localConfirm': 6760,
#    'suspect': 1},
#   {'dead': 15574,
#    'nowConfirm': 888555,
#    'nowSevere': 384,
#    'importedCase': 18373,
#    'healRate': '24.0',
#    'heal': 284897,
#    'deadRate': '1.3',
#    'date': '05.13',
#    'suspect': 1,
#    'y': '2022',
#    'confirm': 1189026,
#    'noInfect': 61780,
#    'localConfirm': 6155,
#    'noInfectH5': 61311,
#    'localConfirmH5': 6155,
#    'local_acc_confirm': 221565},
#   {'dead': 15618,
#    'noInfectH5': 58397,
#    'local_acc_confirm': 221804,
#    'healRate': '22.8',
#    'localConfirmH5': 5945,
#    'deadRate': '1.2',
#    'y': '2022',
#    'nowConfirm': 952224,
#    'nowSevere': 383,
#    'heal': 285435,
#    'importedCase': 18386,
#    'date': '05.14',
#    'noInfect': 58878,
#    'localConfirm': 5945,
#    'confirm': 1253277,
#    'suspect': 0},
#   {'nowSevere': 348,
#    'heal': 286143,
#    'noInfectH5': 52320,
#    'localConfirmH5': 5466,
#    'date': '05.15',
#    'local_acc_confirm': 221955,
#    'importedCase': 18397,
#    'suspect': 0,
#    'dead': 15642,
#    'nowConfirm': 1020408,
#    'deadRate': '1.2',
#    'healRate': '21.6',
#    'y': '2022',
#    'noInfect': 52798,
#    'confirm': 1322193,
#    'localConfirm': 5466},
#   {'confirm': 1384126,
#    'nowSevere': 343,
#    'importedCase': 18410,
#    'y': '2022',
#    'noInfect': 50461,
#    'dead': 15672,
#    'healRate': '20.7',
#    'localConfirm': 5359,
#    'localConfirmH5': 5359,
#    'local_acc_confirm': 222130,
#    'suspect': 0,
#    'nowConfirm': 1081796,
#    'noInfectH5': 50461,
#    'heal': 286658,
#    'deadRate': '1.1',
#    'date': '05.16'},
#   {'heal': 287152,
#    'nowConfirm': 1147370,
#    'nowSevere': 301,
#    'noInfect': 47718,
#    'localConfirmH5': 5027,
#    'confirm': 1450235,
#    'importedCase': 18423,
#    'deadRate': '1.1',
#    'y': '2022',
#    'suspect': 0,
#    'healRate': '19.8',
#    'local_acc_confirm': 222370,
#    'dead': 15713,
#    'date': '05.17',
#    'localConfirm': 5027,
#    'noInfectH5': 47277},
#   {'suspect': 0,
#    'deadRate': '1.0',
#    'healRate': '18.7',
#    'noInfect': 45519,
#    'heal': 287656,
#    'nowConfirm': 1232184,
#    'importedCase': 18444,
#    'y': '2022',
#    'localConfirm': 4839,
#    'noInfectH5': 45100,
#    'nowSevere': 286,
#    'date': '05.18',
#    'localConfirmH5': 4839,
#    'confirm': 1535599,
#    'dead': 15759,
#    'local_acc_confirm': 222582}]}

# %% [markdown]
# ## Part 2. Data Cleaning
#
# We then compare the data with the data displayed in the web page, and analyze the labels' correspondance.
#
# ```json
# {
#     "chinaDayAddList": [
#         {
#             "y": "2022",
#             "confirm": 5451,                 // 新增确诊
#             "suspect": 0,                    // 新增疑似
#             "date": "04.15"
#         }
#     ],
#     "chinaDayList": [
#         {
#             "y": "2022",
#             "nowConfirm": 259560,            // 现有确诊
#             "dead": 14561,                   // 累计死亡
#             "heal": 227416,                  // 累计治愈
#             "confirm": 519822,               // 累计确诊
#             "date": "04.15"
#         }
#     ]
# }
# ```

# %%
import pandas as pd

day_add = pd.DataFrame.from_records(raw_data['chinaDayAddList'])
day_add['date'] = day_add['y'] + '-' + day_add['date'].str.replace('\\.', '-', regex=True)
day_add['date'] = pd.to_datetime(day_add['date'])

day_add.drop(day_add.columns.difference(['date', 'confirm', 'suspect']), axis=1, inplace=True)  # keep only info we need

day_add.sort_values(by='date', inplace=True)
day_add = day_add.tail(30)  # we only need the last 30 days
day_add.fillna(day_add.mean(numeric_only=True), inplace=True)  # fill missing values with mean
day_add['day_bias'] = (day_add['date'] - day_add['date'].min()) / pd.Timedelta('1 days') + 1  # the day from the first day in the seq (30 days)

day_add.tail(5)  # preview
# Out:
#     suspect  confirm       date  day_bias
# 55        0    64238 2022-05-14      26.0
# 56        0    68916 2022-05-15      27.0
# 57        0    61933 2022-05-16      28.0
# 58        0    66109 2022-05-17      29.0
# 59        0    85364 2022-05-18      30.0

# %%
day_info = pd.DataFrame.from_records(raw_data['chinaDayList'])
day_info['date'] = day_info['y'] + '-' + day_info['date'].str.replace('\\.', '-', regex=True)
day_info['date'] = pd.to_datetime(day_info['date'])

day_info.drop(day_info.columns.difference(['date', 'dead', 'heal', 'confirm', 'nowConfirm']), axis=1, inplace=True)  # keep only info we need
day_info.sort_values(by='date', inplace=True)
day_info = day_info.tail(30)  # we only need the last 30 days

day_info.fillna(day_info.mean(numeric_only=True), inplace=True)  # fill missing values with mean
day_info['day_bias'] = (day_info['date'] - day_info['date'].min()) / pd.Timedelta('1 days') + 1  # the day from the first day in the seq (30 days)

day_info.tail(5)  # preview
# Out:
#          date   dead  nowConfirm  confirm    heal  day_bias
# 55 2022-05-14  15618      952224  1253277  285435      26.0
# 56 2022-05-15  15642     1020408  1322193  286143      27.0
# 57 2022-05-16  15672     1081796  1384126  286658      28.0
# 58 2022-05-17  15713     1147370  1450235  287152      29.0
# 59 2022-05-18  15759     1232184  1535599  287656      30.0

# %% [markdown]
# ## Part 3. Linear Regression Models

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np


def modeling(name, x, y):
    print(name)
    # training
    model = LinearRegression()
    X_train, X_test, y_train, y_test = train_test_split(
        x.values.reshape(-1, 1), y, test_size=0.2, shuffle=False)  # time series
    model.fit(X_train, y_train)
    print(f'Y = {model.coef_[0]} * X + {model.intercept_}')

    # validating
    rmse = np.sqrt(mean_squared_error(y_test, model.predict(X_test)))
    print(f'RMSE = {rmse}')

    # predicting
    pred_day_bias = [[x.max() + 1]]  # 2D array for prediction
    print(f'Pred = {model.predict(pred_day_bias)[0]:.3f}')

# %%
modeling('Now Confirm (现有确诊)', day_info['day_bias'], day_info['nowConfirm'])
# Out:
# Now Confirm (现有确诊)
# Y = 21122.561304347822 * X + 185798.35869565222
# RMSE = 297900.18913779483
# Pred = 840597.759

# %%
modeling('New Confirm (新增确诊)', day_add['day_bias'], day_add['confirm'])
# Out:
# New Confirm (新增确诊)
# Y = 2355.0369565217393 * X + -4878.253623188408
# RMSE = 10695.218975876382
# Pred = 68127.892

# %%
modeling('Now Suspect (新增疑似)', day_add['day_bias'], day_add['suspect'])
# Out:
# Now Suspect (新增疑似)
# Y = 0.005217391304347826 * X + 0.10144927536231883
# RMSE = 0.24508956136418178
# Pred = 0.263

# %%
modeling('Accumulated Confirm (累计确诊)', day_info['day_bias'], day_info['confirm'])
# Out:
# Accumulated Confirm (累计确诊)
# Y = 23367.355652173912 * X + 435908.72101449274
# RMSE = 287649.98095579416
# Pred = 1160296.746

# %%
modeling('Accumulated Heal (累计治愈)', day_info['day_bias'], day_info['heal'])
# Out:
# Accumulated Heal (累计治愈)
# Y = 2157.5939130434776 * X + 236454.57608695654
# RMSE = 9852.368743932368
# Pred = 303339.987

# %%
modeling('Accumulated Dead (累计死亡)', day_info['day_bias'], day_info['dead'])
# Out:
# Accumulated Dead (累计死亡)
# Y = 39.44260869565217 * X + 14675.967391304348
# RMSE = 98.06515957287887
# Pred = 15898.688
